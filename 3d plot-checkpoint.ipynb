# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax1 = fig.add_subplot(111,projection='3d')

x= np.array([1,2,3,4])
y=np.array([5,6,7,8])
z=np.array([9,10,11,12])

ax1.scatter(x,y,z)
plt.show()
# Out:
# [1 2 3 4]

# %%
import pandas as pd
df = pd.read_excel('test1.xlsx',sheet_name='Sheet1')
WS_np = np.array(WS)

# %%
print(WS_np.shape[0])
print(WS_np.shape[1])

print("Column headings:")
print(df.columns)
listX = df['X']
listX_np = np.array(listX)
listY = df['Y']
listY_np = np.array(listY)
listZ = df['Z']
listZ_np = np.array(listZ)

fig = plt.figure()
ax1 = fig.add_subplot(111,projection='3d')

ax1.scatter(listX_np,listY_np,listZ_np)
plt.show()
# Out:
# 127
# 3
# Column headings:
# Index(['X', 'Y', 'Z'], dtype='object')
